# %% [markdown]
# <a href="https://colab.research.google.com/github/SitiRohayani/Image_Histogram/blob/main/2006062_Siti_Rohayani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/2006062_Siti Rohayani_A/Siti Rohayani.png", cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=645x363 at 0x7FDF42B08110>

# %%
# original image
plt.imshow(img)

# %% [markdown]
# HISTOGRAM BGR

# %%
#menampilkan histogram
import cv2
import numpy as np
from matplotlib import pyplot as plt

color = ('b','g','r')
for i,col in enumerate(color):
  histr = cv2.calcHist([img],[i],None,[256],[0,256])
  plt.plot(histr,color = col)
  plt.xlim([0,256])
plt.show()

# %%
print(img.size)
print(img.shape)
print(img.dtype)
# Out:
# 702405
# (363, 645, 3)
# uint8

# %% [markdown]
# PLOTING HISTOGRAM

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print(a)
print(a.ravel())
print(a.flatten())
plt.hist(a.ravel(),bins=50, range=[0,50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(img.ravel(), bins=256, range=[0,256])
plt.show()

# %% [markdown]
# BGR BIN 4

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [4], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,4])
plt.show()

# %% [markdown]
# BGR BIN 8

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [8], [0,256])
  plt.plot(histogr, color = col)
  plt.show()

# %% [markdown]
# BGR BIN 16

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [16], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %% [markdown]
# BGR BIN 32

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [32], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %% [markdown]
# SPLIT CHANNEL

# %%
b,g,r = cv2.split(img)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF33781C90>

# %% [markdown]
# BLUE CHANNEL

# %%
#blue channel
bluech = img[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF337CB2D0>

# %%
plt.hist(bluech.ravel(), 16, [0,256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0,256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0,256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# GREEN CHANNEL

# %%
#green channel
greench = img[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF333B23D0>

# %%
plt.hist(bluech.ravel(), 8, [0,256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0,256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0,256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0,256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0,256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# RED CHANNEL

# %%
#red channel
redch = img[:,:,1]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF331E5A90>

# %%
plt.hist(bluech.ravel(), 256, [0,256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0,256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0,256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0,256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0,256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# GRAYSCALE IMAGE HISTOGRAM ANALISYSIS

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF32F11450>

# %%
plt.hist(gray_image.ravel(), bins = 256, range=[0,256])
plt.show()
print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 234135
# (363, 645)
# uint8

# %% [markdown]
# IMAGE TRANSFROM-GRAYSCALE

# %%
invert_gray= 255 - gray_image
cv2_imshow(invert_gray)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7F5ED86E4610>

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# High Brightness Image

# %%
bright_image = (100.0/255)*gray_image+100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7F5ED8DD9750>

# %%
plt.hist(bright_image.ravel(), bins=256, range=[0,256])
plt.show()

# %%
#darken_image = 255.0*(gray_image/255.0)**2
#cv2_imshow(darken_image)

darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=645x363 at 0x7FDF33781110>

# %%
plt.hist(darken_image.ravel(), bins=256, range=[0,256])
plt.show()
